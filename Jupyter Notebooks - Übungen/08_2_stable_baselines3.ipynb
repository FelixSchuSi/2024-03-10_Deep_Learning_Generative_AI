# %% [markdown]
# ## Stablebaselines
# https://stable-baselines3.readthedocs.io/en/master/guide/quickstart.html

# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: stable_baselines3
# Successfully installed stable_baselines3-2.2.1

# %%
import gymnasium as gym

from stable_baselines3 import A2C, DQN
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## CartPole

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### CartPole DQN

# %%
model = DQN("MlpPolicy", env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# A standard 3-layer network is used with
# * length of state vector as input
# * length of action vector as output
# * hidden vector size 64
#
# Different tricks are use to stabilze the learning:
# * replay buffer to store parts of episodes
# * gradient clipping to avoid large steps
# * Two networks of same architecture are used. One for action selection, one for Q-value computation. <br>
# This reduces bias.

# %%
model.policy
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=2, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=2, bias=True)
#     )
#   )
# )

# %% [markdown]
# The architecture can be changed.

# %% [markdown]
# #### Training
# 100k timesteps: 69 sec <br>
# 150k timesteps: 128 sec <br>
# 200k timesteps: 182 sec

# %%
model.learn(total_timesteps=200_000)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 5694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4512     |
# |    fps              | 1820     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72822    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 5705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4516     |
# |    fps              | 1818     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72865    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00934  |
# |    n_updates        | 5716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4520     |
# |    fps              | 1817     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 5726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4524     |
# |    fps              | 1816     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 5737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4528     |
# |    fps              | 1814     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72991    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0594   |
# |    n_updates        | 5747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4532     |
# |    fps              | 1813     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73034    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 5758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4536     |
# |    fps              | 1812     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0512   |
# |    n_updates        | 5768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4540     |
# |    fps              | 1810     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73116    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 5778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4544     |
# |    fps              | 1809     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0554   |
# |    n_updates        | 5789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4548     |
# |    fps              | 1807     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73198    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0459   |
# |    n_updates        | 5799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4552     |
# |    fps              | 1806     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 5810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4556     |
# |    fps              | 1804     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 5822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4560     |
# |    fps              | 1803     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 5833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4564     |
# |    fps              | 1802     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73375    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0692   |
# |    n_updates        | 5843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4568     |
# |    fps              | 1801     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73415    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0686   |
# |    n_updates        | 5853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4572     |
# |    fps              | 1800     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73453    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 5863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4576     |
# |    fps              | 1799     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73491    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 5872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4580     |
# |    fps              | 1797     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0769   |
# |    n_updates        | 5883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4584     |
# |    fps              | 1796     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 5894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4588     |
# |    fps              | 1795     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73620    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0668   |
# |    n_updates        | 5904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4592     |
# |    fps              | 1793     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00275  |
# |    n_updates        | 5915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4596     |
# |    fps              | 1792     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73696    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 5923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4600     |
# |    fps              | 1791     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 5933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4604     |
# |    fps              | 1790     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73773    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0418   |
# |    n_updates        | 5943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4608     |
# |    fps              | 1788     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73815    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 5953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4612     |
# |    fps              | 1787     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 5963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4616     |
# |    fps              | 1786     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73897    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 5974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4620     |
# |    fps              | 1784     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73934    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 5983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4624     |
# |    fps              | 1783     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73975    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 5993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4628     |
# |    fps              | 1782     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74016    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0842   |
# |    n_updates        | 6003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4632     |
# |    fps              | 1781     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74053    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0393   |
# |    n_updates        | 6013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4636     |
# |    fps              | 1779     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74091    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 6022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4640     |
# |    fps              | 1777     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74131    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 6032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4644     |
# |    fps              | 1775     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 6041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4648     |
# |    fps              | 1773     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74203    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00985  |
# |    n_updates        | 6050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4652     |
# |    fps              | 1771     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00426  |
# |    n_updates        | 6059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 9.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4656     |
# |    fps              | 1769     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74280    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00934  |
# |    n_updates        | 6069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.84     |
# |    ep_rew_mean      | 9.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4660     |
# |    fps              | 1767     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 6079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 9.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4664     |
# |    fps              | 1766     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74353    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 6088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4668     |
# |    fps              | 1764     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 6097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4672     |
# |    fps              | 1762     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.072    |
# |    n_updates        | 6107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4676     |
# |    fps              | 1761     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74471    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00626  |
# |    n_updates        | 6117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4680     |
# |    fps              | 1759     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74511    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 6127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4684     |
# |    fps              | 1757     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74551    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 6137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4688     |
# |    fps              | 1755     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74590    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 6147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4692     |
# |    fps              | 1754     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 6156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4696     |
# |    fps              | 1752     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74665    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 6166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4700     |
# |    fps              | 1750     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74705    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 6176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4704     |
# |    fps              | 1748     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74747    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 6186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4708     |
# |    fps              | 1746     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74783    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 6195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4712     |
# |    fps              | 1745     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74822    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 6205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4716     |
# |    fps              | 1743     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74861    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.09     |
# |    n_updates        | 6215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4720     |
# |    fps              | 1741     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74903    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 6225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4724     |
# |    fps              | 1739     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74941    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0488   |
# |    n_updates        | 6235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.63     |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4728     |
# |    fps              | 1736     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74979    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00405  |
# |    n_updates        | 6244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4732     |
# |    fps              | 1734     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75015    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 6253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4736     |
# |    fps              | 1733     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75055    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 6263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4740     |
# |    fps              | 1731     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75099    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 6274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4744     |
# |    fps              | 1729     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75141    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0557   |
# |    n_updates        | 6285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4748     |
# |    fps              | 1727     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 6294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4752     |
# |    fps              | 1725     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 6304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4756     |
# |    fps              | 1723     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75254    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0764   |
# |    n_updates        | 6313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4760     |
# |    fps              | 1722     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75293    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00987  |
# |    n_updates        | 6323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4764     |
# |    fps              | 1720     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75332    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0876   |
# |    n_updates        | 6332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4768     |
# |    fps              | 1718     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 6343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4772     |
# |    fps              | 1716     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00634  |
# |    n_updates        | 6353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4776     |
# |    fps              | 1714     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75450    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0656   |
# |    n_updates        | 6362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4780     |
# |    fps              | 1713     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75487    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.087    |
# |    n_updates        | 6371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4784     |
# |    fps              | 1708     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 6381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4788     |
# |    fps              | 1706     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75566    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0555   |
# |    n_updates        | 6391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 9.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4792     |
# |    fps              | 1705     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75605    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 6401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4796     |
# |    fps              | 1704     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0908   |
# |    n_updates        | 6410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4800     |
# |    fps              | 1703     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 6419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4804     |
# |    fps              | 1702     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75719    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 6429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4808     |
# |    fps              | 1701     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75758    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 6439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4812     |
# |    fps              | 1700     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.056    |
# |    n_updates        | 6449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4816     |
# |    fps              | 1699     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 6458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4820     |
# |    fps              | 1698     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75871    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0702   |
# |    n_updates        | 6467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4824     |
# |    fps              | 1697     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75909    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 6477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4828     |
# |    fps              | 1696     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75949    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 6487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4832     |
# |    fps              | 1691     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75991    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00616  |
# |    n_updates        | 6497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4836     |
# |    fps              | 1688     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76030    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 6507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4840     |
# |    fps              | 1687     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0729   |
# |    n_updates        | 6517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4844     |
# |    fps              | 1686     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0869   |
# |    n_updates        | 6527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4848     |
# |    fps              | 1685     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0523   |
# |    n_updates        | 6538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4852     |
# |    fps              | 1683     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0678   |
# |    n_updates        | 6550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.87     |
# |    ep_rew_mean      | 9.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4856     |
# |    fps              | 1682     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76241    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 6560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 9.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4860     |
# |    fps              | 1681     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76283    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0838   |
# |    n_updates        | 6570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.88     |
# |    ep_rew_mean      | 9.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 1681     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0455   |
# |    n_updates        | 6579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 1680     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76359    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0994   |
# |    n_updates        | 6589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 1678     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76405    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0781   |
# |    n_updates        | 6601     |
# ...
# |    time_elapsed     | 167      |
# |    total_timesteps  | 176012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00805  |
# |    n_updates        | 31502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5724     |
# |    fps              | 1051     |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 176979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 31744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5728     |
# |    fps              | 1050     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 177786   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 31946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5732     |
# |    fps              | 1048     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 179079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 32269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5736     |
# |    fps              | 1047     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 179910   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 32477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5740     |
# |    fps              | 1046     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 180690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 32672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5744     |
# |    fps              | 1045     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 181456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 32863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5748     |
# |    fps              | 1044     |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 182354   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 33088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5752     |
# |    fps              | 1043     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 183403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 33350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5756     |
# |    fps              | 1041     |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 184150   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 33537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5760     |
# |    fps              | 1039     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 185064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.391    |
# |    n_updates        | 33765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5764     |
# |    fps              | 1037     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 185780   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00807  |
# |    n_updates        | 33944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5768     |
# |    fps              | 1036     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 186599   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 34149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5772     |
# |    fps              | 1036     |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 187181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 34295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5776     |
# |    fps              | 1035     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 188013   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.57     |
# |    n_updates        | 34503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5780     |
# |    fps              | 1034     |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 188639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.004    |
# |    n_updates        | 34659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5784     |
# |    fps              | 1033     |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 189452   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.329    |
# |    n_updates        | 34862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5788     |
# |    fps              | 1033     |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 190050   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0832   |
# |    n_updates        | 35012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5792     |
# |    fps              | 1032     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 190847   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.337    |
# |    n_updates        | 35211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5796     |
# |    fps              | 1031     |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 191567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.292    |
# |    n_updates        | 35391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5800     |
# |    fps              | 1030     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 192479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 35619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5804     |
# |    fps              | 1030     |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 193054   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 35763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5808     |
# |    fps              | 1029     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 193910   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.334    |
# |    n_updates        | 35977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5812     |
# |    fps              | 1027     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 194611   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 36152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5816     |
# |    fps              | 1025     |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 195290   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.44     |
# |    n_updates        | 36322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5820     |
# |    fps              | 1024     |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 196062   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 36515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5824     |
# |    fps              | 1023     |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 196811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 36702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 197      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5828     |
# |    fps              | 1022     |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 197442   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 36860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5832     |
# |    fps              | 1021     |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 198257   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 37064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5836     |
# |    fps              | 1021     |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 198948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00615  |
# |    n_updates        | 37236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5840     |
# |    fps              | 1020     |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 199751   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.18     |
# |    n_updates        | 37437    |
# ----------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()

# %%
iprev=0
sm = 0; nn=0
for i in range(2000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    #print(i,obs, reward, "done",done, info)
    if done:
        print(i,i-iprev)
        sm += i-iprev; nn+=1
        iprev=i
    #vec_env.render("human")
print("average",sm/nn)
# Out:
# 175 175
# 324 149
# 459 135
# 670 211
# 920 250
# 1042 122
# 1203 161
# 1341 138
# 1531 190
# 1665 134
# 1802 137
# average 163.8181818181818

# %% [markdown]
# ### PPO

# %% [markdown]
# **Proximal Policy Optimization** (PPO) is a family of model-free reinforcement learning algorithms developed at OpenAI in 2017. PPO algorithms are **policy gradient** methods, which means that they search the space of policies rather than assigning values to state-action pairs. https://arxiv.org/pdf/1707.06347.pdf
#
# PPO algorithms have some of the benefits of trust region policy optimization (TRPO) algorithms, which avoid parameter updates that change the policy too much with a KL divergence constraint on the size of the policy update at each iteration.
# PPO algorithms are simpler to implement, more general, and have better sample complexity.[1] It is done by using a different objective function.[2]

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
# Parallel environments
n_envs = 4
vec_env = make_vec_env("CartPole-v1", n_envs=n_envs)

# %%
model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | 22.4     |
# | time/              |          |
# |    fps             | 2167     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 29.2        |
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014002295 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00328    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.8         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66          |
# |    ep_rew_mean          | 66          |
# | time/                   |             |
# |    fps                  | 1107        |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017192036 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 25          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014116088 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 41.4        |
# -----------------------------------------

# %%
model.save("ppo_cartpole")

# %%
del model # remove to demonstrate saving and loading

model = PPO.load("ppo_cartpole")

# %%
obs = vec_env.reset()
sm = 0; nn=0
for j in range(n_envs):
    print("-----",j)
    iprev=0
    for i in range(2000):
        action, _state = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)
        #print(i,obs, reward, "done",done, info)
        if done[j]:
            print(i,i-iprev)
            sm += i-iprev; nn+=1
            iprev=i
    #vec_env.render("human")
print("average",sm/nn)
# Out:
# ----- 0
# 397 397
# 897 500
# 1280 383
# 1663 383
# 1961 298
# ----- 1
# 422 422
# 737 315
# 1030 293
# 1384 354
# 1884 500
# ----- 2
# 254 254
# 754 500
# 1254 500
# 1601 347
# 1935 334
# ----- 3
# 290 290
# 705 415
# 1071 366
# 1316 245
# 1563 247
# average 367.15

# %% [markdown]
# ### A2C

# %%
model = A2C("MlpPolicy", env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20_000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | 26.1     |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.375    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -3.2     |
# |    value_loss         | 34.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.3     |
# |    ep_rew_mean        | 33.3     |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 0.278    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.707    |
# |    value_loss         | 5.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34.8     |
# |    ep_rew_mean        | 34.8     |
# | time/                 |          |
# |    fps                | 450      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | 0.0317   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.19     |
# |    value_loss         | 7.14     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.3     |
# |    ep_rew_mean        | 37.3     |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | -0.00338 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.04     |
# |    value_loss         | 6.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.2     |
# |    ep_rew_mean        | 40.2     |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | 0.00198  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -8.94    |
# |    value_loss         | 559      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.2     |
# |    ep_rew_mean        | 43.2     |
# | time/                 |          |
# |    fps                | 414      |
# |    iterations         | 600      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | -0.00592 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.732    |
# |    value_loss         | 4.92     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.8      |
# |    ep_rew_mean        | 46.8      |
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 700       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.619    |
# |    explained_variance | -0.000679 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.753     |
# |    value_loss         | 4.19      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 51.4      |
# |    ep_rew_mean        | 51.4      |
# | time/                 |           |
# |    fps                | 425       |
# |    iterations         | 800       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.386    |
# |    explained_variance | -0.000444 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.8       |
# |    value_loss         | 3.67      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.3     |
# |    ep_rew_mean        | 54.3     |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 900      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.492   |
# |    explained_variance | 0.00296  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.06     |
# |    value_loss         | 3.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.4     |
# |    ep_rew_mean        | 58.4     |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 1000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.503   |
# |    explained_variance | 0.00127  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.777    |
# |    value_loss         | 2.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 61.2     |
# |    ep_rew_mean        | 61.2     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 1100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.41    |
# |    explained_variance | 0.000217 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.03     |
# |    value_loss         | 2.26     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 65.3      |
# |    ep_rew_mean        | 65.3      |
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 1200      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.419    |
# |    explained_variance | -0.000103 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.09      |
# |    value_loss         | 1.86      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 67.8     |
# |    ep_rew_mean        | 67.8     |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 1300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.498   |
# |    explained_variance | 0.00031  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.666    |
# |    value_loss         | 1.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.6     |
# |    ep_rew_mean        | 69.6     |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 1400     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | -5.6e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.463    |
# |    value_loss         | 1.21     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 72.6      |
# |    ep_rew_mean        | 72.6      |
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 1500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.537    |
# |    explained_variance | -5.41e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.365     |
# |    value_loss         | 0.936     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.1     |
# |    ep_rew_mean        | 77.1     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 1600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.557   |
# |    explained_variance | 0.000136 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.367    |
# |    value_loss         | 0.684    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.2     |
# |    ep_rew_mean        | 80.2     |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1700     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.552   |
# |    explained_variance | 3.78e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.287    |
# |    value_loss         | 0.477    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84.5      |
# |    ep_rew_mean        | 84.5      |
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 1800      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.499    |
# |    explained_variance | -1.43e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.294     |
# |    value_loss         | 0.304     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.9     |
# |    ep_rew_mean        | 87.9     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 1900     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.545   |
# |    explained_variance | 7.49e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.157    |
# |    value_loss         | 0.169    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 93        |
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 2000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.482    |
# |    explained_variance | -0.000937 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.052     |
# |    value_loss         | 0.0737    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 95.5      |
# |    ep_rew_mean        | 95.5      |
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 2100      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.501    |
# |    explained_variance | -0.000154 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.038     |
# |    value_loss         | 0.0174    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 98.7      |
# |    ep_rew_mean        | 98.7      |
# | time/                 |           |
# |    fps                | 436       |
# |    iterations         | 2200      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.427    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.00955   |
# |    value_loss         | 0.000498  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 102       |
# |    ep_rew_mean        | 102       |
# | time/                 |           |
# |    fps                | 437       |
# |    iterations         | 2300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.451    |
# |    explained_variance | -4.85e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.000418  |
# |    value_loss         | 6.49e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 106      |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.463   |
# |    explained_variance | 0.0148   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.000524 |
# |    value_loss         | 1.92e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 111      |
# |    ep_rew_mean        | 111      |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.448   |
# |    explained_variance | -0.00464 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00038  |
# |    value_loss         | 4.85e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 115       |
# |    ep_rew_mean        | 115       |
# | time/                 |           |
# |    fps                | 437       |
# |    iterations         | 2600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.348    |
# |    explained_variance | -0.000229 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.00152   |
# |    value_loss         | 2.74e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | 119      |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 2700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.346   |
# |    explained_variance | 3.44e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00194  |
# |    value_loss         | 4.62e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 122      |
# |    ep_rew_mean        | 122      |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 2800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | -0.0211  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 2.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 125      |
# |    ep_rew_mean        | 125      |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 2900     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | -0.00501 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000212 |
# |    value_loss         | 2.14e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 125       |
# |    ep_rew_mean        | 125       |
# | time/                 |           |
# |    fps                | 433       |
# |    iterations         | 3000      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.362    |
# |    explained_variance | -2.91e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -3.62e-05 |
# |    value_loss         | 3.52e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 133      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3100     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.349   |
# |    explained_variance | 0.0279   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00297  |
# |    value_loss         | 0.00019  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 134      |
# |    ep_rew_mean        | 134      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3200     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.392   |
# |    explained_variance | -93      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000445 |
# |    value_loss         | 0.000169 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3300     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.392   |
# |    explained_variance | -12.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0164  |
# |    value_loss         | 0.00553  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 3400     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | 0.000958 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 6.45e-05 |
# |    value_loss         | 1.23e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 135      |
# |    ep_rew_mean        | 135      |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 3500     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.308   |
# |    explained_variance | -0.0457  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00527  |
# |    value_loss         | 0.000213 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 130      |
# |    ep_rew_mean        | 130      |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 3600     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.194   |
# |    explained_variance | 0.159    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0126   |
# |    value_loss         | 0.000482 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 117      |
# |    ep_rew_mean        | 117      |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 3700     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.276   |
# |    explained_variance | -3.63    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0373   |
# |    value_loss         | 0.0177   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 115      |
# |    ep_rew_mean        | 115      |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 3800     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.317   |
# |    explained_variance | -10.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -2.94    |
# |    value_loss         | 182      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 108      |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 3900     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.361   |
# |    explained_variance | -1.6     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.592    |
# |    value_loss         | 5.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | 104      |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 4000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.291   |
# |    explained_variance | 0.0829   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.193    |
# |    value_loss         | 0.848    |
# ------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
iprev=0
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    #print(i,obs, reward, "done",done, info)
    if done:
        print(i,i-iprev)
        iprev=i
    #vec_env.render("human")
# Out:
# 93 93
# 195 102
# 284 89
# 365 81
# 424 59
# 559 135
# 642 83
# 717 75
# 800 83
# 892 92
# 985 93
